# %%
import pandas as pd

# %% [markdown]
# ### Liar Fake News Detection
#
# https://www.kaggle.com/datasets/mubarakdaha/liar-fake-news-detection

# %%
liar_fake_news_detection = pd.read_csv("../data/liar_fake_news_detection/myfile.csv")

# %%
liar_fake_news_detection.head(10)
# Out:
#                                                 text label
# 0  Democratic National Committee Chair Debbie Was...     0
# 1  ANKARA (Reuters) - Many Iranians who dreamt of...     1
# 2  This video brilliantly dispels every one of Hi...     0
# 3  DES MOINES, Iowa (Reuters) - U.S. Democratic p...     1
# 4  ABU DHABI (Reuters) - - Hillary Clinton’s vict...     1
# 5  Donald Trump and his team are getting absolute...     0
# 6  WASHINGTON (Reuters) - The U.S. Department of ...     1
# 7  WASHINGTON (Reuters) - The United States carri...     1
# 8  WASHINGTON (Reuters) - U.S. Defense Secretary ...     1
# 9  Donald Trump has a strategy to defeat Hillary ...     0

# %%
liar_fake_news_detection["label"].value_counts()
# Out:
# label
# 0                                                                                                                                                                                                                                                                                                                                                                       23432
# 1                                                                                                                                                                                                                                                                                                                                                                       21400
# ...

# %%
liar_fake_news_detection["label"].astype(str)
liar_fake_news_detection.dtypes
# Out:
# text     str
# label    str
# dtype: object

# %%
liar_fake_news_detection = liar_fake_news_detection[liar_fake_news_detection["label"].isin(["0", "1"])]
liar_fake_news_detection["label"].value_counts()
# Out:
# label
# 0    23432
# 1    21400
# Name: count, dtype: int64

# %%
liar_fake_news_detection.to_csv("../data/datasets/liar_dataset.csv")

# %%
pd.set_option("display.max_colwidth", None)
liar_fake_news_detection[liar_fake_news_detection["label"] == "0"].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
